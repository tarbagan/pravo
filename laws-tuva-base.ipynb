# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize

# %%
file = '/kaggle/input/laws-tuva/base.txt'
f = open(file, encoding='utf8')
data = [eval(us) for us in f]
df = pd.json_normalize(data)
for i in df.title:
    print(i)
# Out:
# Постановление Правительства Республики Тыва от 14.08.2020 № 372 "О внесении изменения в пункт 1 постановления Правительства Республики Тыва от 1 апреля 2020 г. № 122"
# Постановление Правительства Республики Тыва от 14.08.2020 № 371 "О внесении изменения в структуру Министерства юстиции Республики Тыва"
# Указ Главы - Председателя Правительства Республики Тыва от 10.08.2020 № 195 "О внесении изменений в состав комиссии по государственным наградам при Главе Республики Тыва"
# Распоряжение Главы - Председателя Правительства Республики Тыва от 13.08.2020 № 282-РГ "О внесении изменения в состав Президиума Совета директоров общеобразовательных организаций при Главе Республики Тыва"
# Распоряжение Главы - Председателя Правительства Республики Тыва от 12.08.2020 № 281-РГ "О введении режима функционирования "Чрезвычайная ситуация" регионального характера для органов управления и сил территориальной подсистемы предупреждения и ликвидации чрезвычайных ситуаций Республики Тыва"
# ...

# %%
df
